# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Step1 Load the data

# %%
df = pd.read_csv('auto.txt')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ## Stpe 2: cleaning data

# %%
import numpy as np

df = df.replace('?',np.nan)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['make'].unique()

make_dict = {
    'make':{
        'alfa-romero' :1,
        'audi' :2,
        'bmw' :3,
        'chevrolet' :4,
        'dodge' : 5,
        'honda' : 6,
        'isuzu' : 7,
        'jaguar' : 8, 
        'mazda' : 9, 
        'mercedes-benz' :10,
        'mercury' : 11,
       'mitsubishi' : 12, 
        'nissan' :13, 
        'peugot' :14, 
        'plymouth' : 15, 
        'porsche' : 16,
        'renault' :17,
       'saab' :18,
        'subaru' :19, 
        'toyota' :20, 
        'volkswagen' :21, 
        'volvo' :22
    }
}
df.replace(make_dict,inplace=True)
df['make'] = pd.to_numeric(df['make'])

# %%
df['fuel-type'].unique()
fuel_type = {
    'gas':1,
    'diesel':2
}
df['fuel-type'].replace(fuel_type,inplace=True)
df['fuel-type'] = pd.to_numeric(df['fuel-type'])

# %%
df['aspiration'].unique()
asp_dict ={
    'aspiration':{
        'std' :1,
        'turbo' :2
    }
}
df.replace(asp_dict,inplace=True)
df['aspiration'] = pd.to_numeric(df['aspiration'])

# %%
df['num-of-doors'].unique()
num_doors = {
    'four':4,
    'two':2
}
df['num-of-doors'].replace(num_doors,inplace=True)
df['num-of-doors'] = pd.to_numeric(df['num-of-doors'])

# %%
df['body-style'].unique()

df.replace(df['body-style'].unique(),
           range(1,len(df['body-style'].unique())+1),
           inplace=True)

# %%
df['drive-wheels'].unique()
df.replace(df['drive-wheels'].unique(),
          range(1,len(df['drive-wheels'].unique())+1),
           inplace=True)

# %%
df['engine-location'].unique()
df.replace(df['engine-location'].unique(),
          range(1,len(df['engine-location'].unique())+1),
          inplace=True)

# %%
dict = {
    'one':1,
    'two':2,
    'three':3,
    'four':4,
    'five':5,
    'six':6,
    'seven':7,
    'eight':8,
    'nine':9,
    'ten':10,
    'twelve':12
}
df['num-of-cylinders'].replace(dict,inplace=True)
df['num-of-cylinders'] = pd.to_numeric(df['num-of-cylinders'])

# %%
engine_type = {
    'dohc':1,
    'dohcv':2,
    'l':3,
    'ohc':4,
    'ohcf':5,
    'ohcv':6,
    'rotor':7
}
df['engine-type'].replace(engine_type,inplace=True)
df['engine-type'] = pd.to_numeric(df['engine-type'])

# %%
fule_sys = {
    '1bbl':1,
    '2bbl':2,
    '4bbl':4,
    'idi':5,
    'mfi':6,
    'mpfi':7,
    'spdi':8,
    'spfi':9
}
df['fuel-system'].replace(fule_sys,inplace=True)
df['fuel-system'] = pd.to_numeric(df['fuel-system'])

# %%
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['horsepower'] = pd.to_numeric(df['horsepower'],errors='coerce')
df['peak-rpm'] = pd.to_numeric(df['peak-rpm'],errors='coerce')
df['bore'] = pd.to_numeric(df['bore'],errors='coerce')
df['stroke'] = pd.to_numeric(df['stroke'],errors = 'coerce')

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                   int64
# fuel-type              int64
# aspiration             int64
# num-of-doors         float64
# body-style             int64
# drive-wheels           int64
# engine-location        int64
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type            int64
# num-of-cylinders       int64
# engine-size            int64
# fuel-system            int64
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.drop('symboling',axis=1,inplace=True)
df.drop('normalized-losses',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0     1          1           1           2.0           1             1
# 1     1          1           1           2.0           1             1
# 2     1          1           1           2.0           2             1
# 3     2          1           1           4.0           3             2
# 4     2          1           1           4.0           3             3
# 5     2          1           1           2.0           3             2
# 6     2          1           1           4.0           3             2
# 7     2          1           1           4.0           4             2
# 8     2          1           2           4.0           3             2
# 9     2          1           2           2.0           2             3
#
#    engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0                1        88.6   168.8   64.1  ...          130            7
# ...

# %%
df.isna().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
fillna_dict = {
    'num-of-doors' : df['num-of-doors'].mean(),
    'bore' :df['bore'].mean(),
    'stroke' : df['stroke'].mean(),
    'horsepower' :df['horsepower'].mean(),
    'peak-rpm' :df['peak-rpm'].mean(),
    'price' :df['price'].mean()
}
df.fillna(fillna_dict,inplace=True)

# %%
df.drop(['horsepower','curb-weight','peak-rpm','length','city-mpg'],inplace=True,axis=1)

# %%
from sklearn.model_selection import train_test_split

inputs_coulmns = df.drop('price',axis=1)
output_coulmns = df['price']

x_train,x_test,y_train,y_test = train_test_split(inputs_coulmns,output_coulmns,random_state=0,test_size=0.2)

# %%
# from sklearn.impute import SimpleImputer

# fill_zeros = SimpleImputer(missing_values=0,strategy='mean')

# x_train = fill_zeros.fit_transform(x_train)
# x_test = fill_zeros.fit_transform(x_test)

# %% [markdown]
# ## Step 3: Training and Testing

# %%
from sklearn.linear_model import LinearRegression
lmodel = LinearRegression()
lmodel.fit(x_train,y_train.ravel())
# Out:
# LinearRegression()

# %%
# lmodel.score(x_test,y_test)

# %%
pd.Series(lmodel.coef_,x_train.columns).sort_values()
# Out:
# fuel-type           -10381.534575
# bore                 -4093.907320
# stroke               -3282.094393
# drive-wheels         -1761.427068
# num-of-cylinders     -1184.592964
# body-style            -503.645813
# make                  -166.072552
# highway-mpg           -133.641456
# wheel-base              23.363999
# engine-type             96.827533
# fuel-system            121.798587
# engine-size            129.669352
# height                 136.545653
# num-of-doors           524.878559
# compression-ratio      819.692177
# width                  940.662669
# aspiration            1566.380389
# engine-location      15778.775940
# dtype: float64

# %%
predict_value = lmodel.predict(x_test)
plt.figure(figsize=(10,5))
plt.plot(y_test.values,label='Actual Value')
plt.plot(predict_value,label= 'Predicted value')
plt.legend()

# %%
from sklearn.metrics import mean_squared_error
liner_mse = mean_squared_error(predict_value,y_test) 
liner_mse
# Out:
# 18493851.28611238

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.linear_model import Ridge
